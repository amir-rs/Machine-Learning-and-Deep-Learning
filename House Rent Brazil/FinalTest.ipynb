# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.decomposition import PCA
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras

sns.set_style('whitegrid')

# Load the dataset
df = pd.read_csv('houses_to_rent_brazil_kaggle.csv')

# Data Preprocessing
df = df[df['floor'] != '-']  # Remove rows with '-' in the 'floor' column
df = pd.get_dummies(df, columns=['city', 'animal', 'furniture'])

# Define your features (X) and target variable (y)
X = df.drop(columns=['total (R$)'])  # Features
y = df['total (R$)']  # Target variable

# Linear Regression
lr = LinearRegression()
lr.fit(X, y)

targets = df['rent amount (R$)']

x_train, x_test, y_train, y_test = train_test_split(df, targets, test_size=0.3, random_state=42)
kf = KFold(n_splits=5, shuffle=True, random_state=42) 
cross_val_scores = cross_val_score(lr, x_train, y_train, cv=kf, scoring='r2')
print("Cross-validation scores:", cross_val_scores)
print("Mean R^2:", cross_val_scores.mean())

# PCA (Principal Component Analysis)
pca = PCA(n_components=11)
df_pca = pca.fit_transform(X)
df_pca = pd.DataFrame(df_pca, columns=['PCA1', 'PCA2', 'PCA3', 'PCA4', 'PCA5', 'PCA6', 'PCA7', 'PCA8', 'PCA9', 'PCA10', 'PCA11'])

# Model Comparison
x_train, x_test, y_train, y_test = train_test_split(df_pca, y, test_size=0.3, random_state=42)

# Linear Regression
lr = LinearRegression()
lr.fit(x_train, y_train)
y_pred_lr = lr.predict(x_test)
mse_lr = mean_squared_error(y_test, y_pred_lr)
r2_lr = r2_score(y_test, y_pred_lr)
print("Linear Regression Mean Squared Error:", mse_lr)
print("Linear Regression R^2 Score:", r2_lr)
# SVM Regressor
svm_regressor = SVR()
svm_regressor.fit(x_train, y_train)
y_pred_svm = svm_regressor.predict(x_test)
mse_svm = mean_squared_error(y_test, y_pred_svm)
r2_svm = r2_score(y_test, y_pred_svm)
print("SVM Mean Squared Error:", mse_svm)
print("SVM R^2 Score:", r2_svm)
# Random Forest Regressor
rf_regressor = RandomForestRegressor()
rf_regressor.fit(x_train, y_train)
y_pred_rf = rf_regressor.predict(x_test)
mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)
print("Random Forest Mean Squared Error:", mse_rf)
print("Random Forest R^2 Score:", r2_rf)
# XGBoost Regressor
xgb_regressor = XGBRegressor()
xgb_regressor.fit(x_train, y_train)
y_pred_xgb = xgb_regressor.predict(x_test)
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
r2_xgb = r2_score(y_test, y_pred_xgb)
print("XGBoost Mean Squared Error:", mse_xgb)
print("XGBoost R^2 Score:", r2_xgb)
# Ridge Regression
ridge_regressor = Ridge(alpha=1.0)
ridge_regressor.fit(x_train, y_train)
y_pred_ridge = ridge_regressor.predict(x_test)
mse_ridge = mean_squared_error(y_test, y_pred_ridge)
r2_ridge = r2_score(y_test, y_pred_ridge)
print("Ridge Mean Squared Error:", mse_ridge)
print("Ridge R^2 Score:", r2_ridge)

# Example of predicting rent for new data
original_cols = x_train.columns
new_data = pd.DataFrame([[4, 100, 2, 1, 2, 2, 0, 0, 1000, 500, 40]], columns=original_cols)
predicted_rent = lr.predict(new_data)
print("Predicted Rent (Linear Regression):", predicted_rent[0])

# Neural Network Model
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

model = keras.Sequential([
    keras.layers.Input(shape=(X_train_scaled.shape[1],)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

history = model.fit(X_train_scaled, y_train, epochs=100, batch_size=32, validation_data=(X_test_scaled, y_test))
mse, mae = model.evaluate(X_test_scaled, y_test)
print(f'Mean Squared Error (Neural Network): {mse}')
print(f'Mean Absolute Error (Neural Network): {mae}')

new_data_scaled = scaler.transform(new_data)
predicted_rent = model.predict(new_data_scaled)
print("Predicted Rent (Neural Network):", predicted_rent[0][0])
# Out:
# Cross-validation scores: [1. 1. 1. 1. 1.]
# Mean R^2: 1.0
# Linear Regression Mean Squared Error: 59.301799464344285
# Linear Regression R^2 Score: 0.9999998980623702
# SVM Mean Squared Error: 584303984.1214895
# SVM R^2 Score: -0.0043972312900550925
# Random Forest Mean Squared Error: 69615355.36308435
# Random Forest R^2 Score: 0.880333743937955
# Ridge Mean Squared Error: 59.30162466845111
# Ridge R^2 Score: 0.9999998980626708
# Predicted Rent (Linear Regression): 5543.766125778419
# Epoch 1/100
# 181/181 [==============================] - 4s 11ms/step - loss: 270906592.0000 - mean_absolute_error: 5266.7417 - val_loss: 601443904.0000 - val_mean_absolute_error: 5521.4028
# Epoch 2/100
# 181/181 [==============================] - 2s 8ms/step - loss: 265169872.0000 - mean_absolute_error: 4953.6099 - val_loss: 587532160.0000 - val_mean_absolute_error: 5170.0430
# Epoch 3/100
# 181/181 [==============================] - 2s 8ms/step - loss: 256712160.0000 - mean_absolute_error: 4514.9741 - val_loss: 563814592.0000 - val_mean_absolute_error: 4522.4224
# Epoch 4/100
# 181/181 [==============================] - 2s 9ms/step - loss: 244522176.0000 - mean_absolute_error: 3713.9907 - val_loss: 537404352.0000 - val_mean_absolute_error: 3633.8057
# Epoch 5/100
# 181/181 [==============================] - 3s 16ms/step - loss: 232103712.0000 - mean_absolute_error: 2811.4207 - val_loss: 512483456.0000 - val_mean_absolute_error: 2554.0615
# Epoch 6/100
# 181/181 [==============================] - 4s 23ms/step - loss: 221687056.0000 - mean_absolute_error: 1830.4098 - val_loss: 496540640.0000 - val_mean_absolute_error: 1735.6182
# Epoch 7/100
# 181/181 [==============================] - 4s 23ms/step - loss: 215210080.0000 - mean_absolute_error: 1215.5145 - val_loss: 487186144.0000 - val_mean_absolute_error: 1334.5802
# Epoch 8/100
# 181/181 [==============================] - 4s 20ms/step - loss: 211079088.0000 - mean_absolute_error: 934.9093 - val_loss: 480661984.0000 - val_mean_absolute_error: 1228.7960
# Epoch 9/100
# 181/181 [==============================] - 4s 19ms/step - loss: 208063472.0000 - mean_absolute_error: 916.1808 - val_loss: 475272128.0000 - val_mean_absolute_error: 1229.8524
# Epoch 10/100
# 181/181 [==============================] - 4s 20ms/step - loss: 205448208.0000 - mean_absolute_error: 940.7397 - val_loss: 469735456.0000 - val_mean_absolute_error: 1254.0663
# Epoch 11/100
# 181/181 [==============================] - 4s 24ms/step - loss: 202780096.0000 - mean_absolute_error: 907.8098 - val_loss: 463616960.0000 - val_mean_absolute_error: 1314.2747
# Epoch 12/100
# 181/181 [==============================] - 4s 20ms/step - loss: 199934880.0000 - mean_absolute_error: 928.2646 - val_loss: 457966784.0000 - val_mean_absolute_error: 1357.3478
# Epoch 13/100
# 181/181 [==============================] - 3s 17ms/step - loss: 197016352.0000 - mean_absolute_error: 1079.9124 - val_loss: 450761344.0000 - val_mean_absolute_error: 1372.1925
# Epoch 14/100
# 181/181 [==============================] - 3s 18ms/step - loss: 194154576.0000 - mean_absolute_error: 986.2505 - val_loss: 444228064.0000 - val_mean_absolute_error: 1391.8187
# Epoch 15/100
# 181/181 [==============================] - 2s 13ms/step - loss: 191084464.0000 - mean_absolute_error: 992.7585 - val_loss: 437394944.0000 - val_mean_absolute_error: 1409.7544
# Epoch 16/100
# 181/181 [==============================] - 1s 7ms/step - loss: 187926624.0000 - mean_absolute_error: 1066.4199 - val_loss: 429602912.0000 - val_mean_absolute_error: 1407.2983
# Epoch 17/100
# 181/181 [==============================] - 1s 8ms/step - loss: 184769952.0000 - mean_absolute_error: 1028.4329 - val_loss: 422045088.0000 - val_mean_absolute_error: 1398.4622
# Epoch 18/100
# 181/181 [==============================] - 2s 10ms/step - loss: 181415776.0000 - mean_absolute_error: 1085.0620 - val_loss: 414266816.0000 - val_mean_absolute_error: 1356.5341
# Epoch 19/100
# 181/181 [==============================] - 2s 10ms/step - loss: 178071344.0000 - mean_absolute_error: 996.9661 - val_loss: 406218176.0000 - val_mean_absolute_error: 1351.8798
# Epoch 20/100
# 181/181 [==============================] - 2s 13ms/step - loss: 174495120.0000 - mean_absolute_error: 980.6107 - val_loss: 397864928.0000 - val_mean_absolute_error: 1339.1121
# Epoch 21/100
# 181/181 [==============================] - 2s 12ms/step - loss: 170833072.0000 - mean_absolute_error: 1020.3172 - val_loss: 389308640.0000 - val_mean_absolute_error: 1313.6887
# Epoch 22/100
# 181/181 [==============================] - 2s 12ms/step - loss: 167109360.0000 - mean_absolute_error: 909.4640 - val_loss: 383381600.0000 - val_mean_absolute_error: 1258.3604
# Epoch 23/100
# 181/181 [==============================] - 2s 11ms/step - loss: 163167456.0000 - mean_absolute_error: 920.6370 - val_loss: 373176480.0000 - val_mean_absolute_error: 1270.8894
# Epoch 24/100
# 181/181 [==============================] - 2s 13ms/step - loss: 159108016.0000 - mean_absolute_error: 984.6398 - val_loss: 361639008.0000 - val_mean_absolute_error: 1282.5465
# Epoch 25/100
# 181/181 [==============================] - 2s 12ms/step - loss: 155093120.0000 - mean_absolute_error: 980.3229 - val_loss: 352210816.0000 - val_mean_absolute_error: 1228.7483
# Epoch 26/100
# 181/181 [==============================] - 2s 12ms/step - loss: 151032208.0000 - mean_absolute_error: 844.8219 - val_loss: 344077376.0000 - val_mean_absolute_error: 1205.1804
# Epoch 27/100
# 181/181 [==============================] - 2s 12ms/step - loss: 147065408.0000 - mean_absolute_error: 881.6310 - val_loss: 332899424.0000 - val_mean_absolute_error: 1203.3512
# Epoch 28/100
# 181/181 [==============================] - 2s 12ms/step - loss: 142692992.0000 - mean_absolute_error: 827.8466 - val_loss: 325200736.0000 - val_mean_absolute_error: 1158.4304
# Epoch 29/100
# 181/181 [==============================] - 2s 13ms/step - loss: 138222624.0000 - mean_absolute_error: 859.0294 - val_loss: 312251328.0000 - val_mean_absolute_error: 1185.4819
# Epoch 30/100
# 181/181 [==============================] - 2s 14ms/step - loss: 133725280.0000 - mean_absolute_error: 816.9633 - val_loss: 302258464.0000 - val_mean_absolute_error: 1167.9167
# Epoch 31/100
# 181/181 [==============================] - 2s 10ms/step - loss: 129210176.0000 - mean_absolute_error: 884.2779 - val_loss: 291429984.0000 - val_mean_absolute_error: 1119.8468
# Epoch 32/100
# 181/181 [==============================] - 3s 15ms/step - loss: 124637336.0000 - mean_absolute_error: 864.0179 - val_loss: 282900544.0000 - val_mean_absolute_error: 1046.9142
# Epoch 33/100
# 181/181 [==============================] - 2s 12ms/step - loss: 120868232.0000 - mean_absolute_error: 744.1084 - val_loss: 271873248.0000 - val_mean_absolute_error: 1056.7319
# Epoch 34/100
# 181/181 [==============================] - 2s 11ms/step - loss: 116063448.0000 - mean_absolute_error: 801.3149 - val_loss: 261078976.0000 - val_mean_absolute_error: 1016.7594
# Epoch 35/100
# 181/181 [==============================] - 2s 12ms/step - loss: 111407512.0000 - mean_absolute_error: 760.3478 - val_loss: 250417984.0000 - val_mean_absolute_error: 1002.9017
# Epoch 36/100
# 181/181 [==============================] - 3s 15ms/step - loss: 106721968.0000 - mean_absolute_error: 757.9714 - val_loss: 239666288.0000 - val_mean_absolute_error: 958.3975
# Epoch 37/100
# 181/181 [==============================] - 2s 11ms/step - loss: 102013544.0000 - mean_absolute_error: 698.2998 - val_loss: 228716736.0000 - val_mean_absolute_error: 960.9965
# Epoch 38/100
# 181/181 [==============================] - 2s 9ms/step - loss: 97391544.0000 - mean_absolute_error: 726.0441 - val_loss: 218054544.0000 - val_mean_absolute_error: 919.0721
# Epoch 39/100
# 181/181 [==============================] - 2s 9ms/step - loss: 92585608.0000 - mean_absolute_error: 629.8345 - val_loss: 207642240.0000 - val_mean_absolute_error: 938.0565
# Epoch 40/100
# 181/181 [==============================] - 2s 9ms/step - loss: 87787408.0000 - mean_absolute_error: 702.8478 - val_loss: 196272048.0000 - val_mean_absolute_error: 902.9584
# Epoch 41/100
# 181/181 [==============================] - 2s 8ms/step - loss: 83136640.0000 - mean_absolute_error: 704.7628 - val_loss: 186093088.0000 - val_mean_absolute_error: 843.1113
# Epoch 42/100
# 181/181 [==============================] - 2s 9ms/step - loss: 78672680.0000 - mean_absolute_error: 598.8182 - val_loss: 175440128.0000 - val_mean_absolute_error: 868.7869
# Epoch 43/100
# 181/181 [==============================] - 2s 13ms/step - loss: 74136416.0000 - mean_absolute_error: 567.0251 - val_loss: 167621088.0000 - val_mean_absolute_error: 866.3091
# Epoch 44/100
# 181/181 [==============================] - 2s 13ms/step - loss: 69389616.0000 - mean_absolute_error: 590.1105 - val_loss: 163009648.0000 - val_mean_absolute_error: 750.4545
# Epoch 45/100
# 181/181 [==============================] - 3s 15ms/step - loss: 64883996.0000 - mean_absolute_error: 609.2839 - val_loss: 143903856.0000 - val_mean_absolute_error: 862.2921
# Epoch 46/100
# 181/181 [==============================] - 2s 13ms/step - loss: 60397884.0000 - mean_absolute_error: 577.8707 - val_loss: 134139576.0000 - val_mean_absolute_error: 843.6588
# Epoch 47/100
# 181/181 [==============================] - 3s 17ms/step - loss: 56012000.0000 - mean_absolute_error: 611.9549 - val_loss: 124796144.0000 - val_mean_absolute_error: 748.1956
# Epoch 48/100
# 181/181 [==============================] - 2s 11ms/step - loss: 51886004.0000 - mean_absolute_error: 511.0946 - val_loss: 115223616.0000 - val_mean_absolute_error: 758.6211
# Epoch 49/100
# 181/181 [==============================] - 2s 9ms/step - loss: 47783504.0000 - mean_absolute_error: 573.9305 - val_loss: 106560720.0000 - val_mean_absolute_error: 678.5070
# Epoch 50/100
# 181/181 [==============================] - 2s 10ms/step - loss: 43924660.0000 - mean_absolute_error: 495.2318 - val_loss: 97784272.0000 - val_mean_absolute_error: 680.9919
# Epoch 51/100
# 181/181 [==============================] - 2s 10ms/step - loss: 40144208.0000 - mean_absolute_error: 502.0771 - val_loss: 89425872.0000 - val_mean_absolute_error: 639.5883
# Epoch 52/100
# 181/181 [==============================] - 2s 9ms/step - loss: 36464684.0000 - mean_absolute_error: 453.1011 - val_loss: 81046288.0000 - val_mean_absolute_error: 647.8188
# Epoch 53/100
# 181/181 [==============================] - 2s 10ms/step - loss: 32886886.0000 - mean_absolute_error: 468.7255 - val_loss: 73338696.0000 - val_mean_absolute_error: 602.9345
# Epoch 54/100
# 181/181 [==============================] - 1s 8ms/step - loss: 29524508.0000 - mean_absolute_error: 461.6806 - val_loss: 66441052.0000 - val_mean_absolute_error: 569.3844
# Epoch 55/100
# 181/181 [==============================] - 1s 7ms/step - loss: 26449412.0000 - mean_absolute_error: 412.0960 - val_loss: 59310148.0000 - val_mean_absolute_error: 540.2608
# Epoch 56/100
# 181/181 [==============================] - 2s 9ms/step - loss: 23388866.0000 - mean_absolute_error: 398.9829 - val_loss: 52453688.0000 - val_mean_absolute_error: 519.5221
# Epoch 57/100
# 181/181 [==============================] - 2s 9ms/step - loss: 20538710.0000 - mean_absolute_error: 379.9787 - val_loss: 46316064.0000 - val_mean_absolute_error: 514.1868
# Epoch 58/100
# 181/181 [==============================] - 2s 10ms/step - loss: 17871584.0000 - mean_absolute_error: 359.1124 - val_loss: 40390104.0000 - val_mean_absolute_error: 507.8631
# Epoch 59/100
# 181/181 [==============================] - 2s 12ms/step - loss: 15371738.0000 - mean_absolute_error: 379.7837 - val_loss: 35547248.0000 - val_mean_absolute_error: 442.3773
# Epoch 60/100
# 181/181 [==============================] - 3s 17ms/step - loss: 13194120.0000 - mean_absolute_error: 313.5310 - val_loss: 30184734.0000 - val_mean_absolute_error: 461.9739
# Epoch 61/100
# 181/181 [==============================] - 1s 8ms/step - loss: 11077763.0000 - mean_absolute_error: 348.3040 - val_loss: 26215472.0000 - val_mean_absolute_error: 379.6689
# Epoch 62/100
# 181/181 [==============================] - 1s 6ms/step - loss: 9309469.0000 - mean_absolute_error: 301.5648 - val_loss: 22225002.0000 - val_mean_absolute_error: 359.7845
# Epoch 63/100
# 181/181 [==============================] - 2s 12ms/step - loss: 7669640.0000 - mean_absolute_error: 256.6357 - val_loss: 18341272.0000 - val_mean_absolute_error: 421.8604
# Epoch 64/100
# 181/181 [==============================] - 3s 17ms/step - loss: 6131449.5000 - mean_absolute_error: 278.2526 - val_loss: 14874617.0000 - val_mean_absolute_error: 357.0773
# Epoch 65/100
# 181/181 [==============================] - 3s 16ms/step - loss: 4865720.5000 - mean_absolute_error: 264.7415 - val_loss: 12410877.0000 - val_mean_absolute_error: 303.2173
# Epoch 66/100
# 181/181 [==============================] - 3s 15ms/step - loss: 3769540.5000 - mean_absolute_error: 230.3800 - val_loss: 9883978.0000 - val_mean_absolute_error: 311.3788
# Epoch 67/100
# 181/181 [==============================] - 2s 13ms/step - loss: 2845196.0000 - mean_absolute_error: 218.7411 - val_loss: 7781444.0000 - val_mean_absolute_error: 303.6631
# Epoch 68/100
# 181/181 [==============================] - 3s 14ms/step - loss: 2091293.6250 - mean_absolute_error: 209.4588 - val_loss: 6201398.5000 - val_mean_absolute_error: 270.9996
# Epoch 69/100
# 181/181 [==============================] - 3s 16ms/step - loss: 1492849.5000 - mean_absolute_error: 186.0532 - val_loss: 5093855.0000 - val_mean_absolute_error: 267.5456
# Epoch 70/100
# 181/181 [==============================] - 3s 18ms/step - loss: 1029445.0000 - mean_absolute_error: 194.2941 - val_loss: 4143046.2500 - val_mean_absolute_error: 208.0788
# Epoch 71/100
# 181/181 [==============================] - 3s 15ms/step - loss: 702590.2500 - mean_absolute_error: 161.8643 - val_loss: 3272102.5000 - val_mean_absolute_error: 192.9173
# Epoch 72/100
# 181/181 [==============================] - 2s 14ms/step - loss: 449886.3750 - mean_absolute_error: 145.7428 - val_loss: 2510929.5000 - val_mean_absolute_error: 194.1473
# Epoch 73/100
# 181/181 [==============================] - 2s 13ms/step - loss: 279284.1250 - mean_absolute_error: 139.7538 - val_loss: 2066597.8750 - val_mean_absolute_error: 179.1451
# Epoch 74/100
# 181/181 [==============================] - 3s 16ms/step - loss: 166681.8906 - mean_absolute_error: 128.5585 - val_loss: 1686528.8750 - val_mean_absolute_error: 160.4419
# Epoch 75/100
# 181/181 [==============================] - 3s 14ms/step - loss: 100176.8281 - mean_absolute_error: 116.7096 - val_loss: 1460327.3750 - val_mean_absolute_error: 155.4161
# Epoch 76/100
# 181/181 [==============================] - 3s 16ms/step - loss: 57479.6172 - mean_absolute_error: 109.0187 - val_loss: 1301086.5000 - val_mean_absolute_error: 127.0522
# Epoch 77/100
# 181/181 [==============================] - 4s 21ms/step - loss: 35838.0039 - mean_absolute_error: 100.7900 - val_loss: 1068658.5000 - val_mean_absolute_error: 125.8012
# Epoch 78/100
# 181/181 [==============================] - 3s 16ms/step - loss: 25185.5254 - mean_absolute_error: 95.2645 - val_loss: 952379.6875 - val_mean_absolute_error: 113.6933
# Epoch 79/100
# 181/181 [==============================] - 3s 15ms/step - loss: 20588.9434 - mean_absolute_error: 88.6420 - val_loss: 868593.8750 - val_mean_absolute_error: 109.4553
# Epoch 80/100
# 181/181 [==============================] - 3s 18ms/step - loss: 16964.0000 - mean_absolute_error: 83.6965 - val_loss: 786041.8125 - val_mean_absolute_error: 96.5391
# Epoch 81/100
# 181/181 [==============================] - 3s 15ms/step - loss: 22551.5195 - mean_absolute_error: 79.6971 - val_loss: 705657.0625 - val_mean_absolute_error: 98.2579
# Epoch 82/100
# 181/181 [==============================] - 3s 15ms/step - loss: 16944.9336 - mean_absolute_error: 75.7734 - val_loss: 635349.5625 - val_mean_absolute_error: 89.6124
# Epoch 83/100
# 181/181 [==============================] - 3s 16ms/step - loss: 13719.8398 - mean_absolute_error: 72.3747 - val_loss: 589770.5000 - val_mean_absolute_error: 90.2462
# Epoch 84/100
# 181/181 [==============================] - 2s 14ms/step - loss: 11456.9648 - mean_absolute_error: 68.2171 - val_loss: 541389.1250 - val_mean_absolute_error: 83.6922
# Epoch 85/100
# 181/181 [==============================] - 4s 20ms/step - loss: 10778.2627 - mean_absolute_error: 65.9370 - val_loss: 511087.6875 - val_mean_absolute_error: 76.9461
# Epoch 86/100
# 181/181 [==============================] - 3s 15ms/step - loss: 10465.2822 - mean_absolute_error: 63.7804 - val_loss: 472853.0000 - val_mean_absolute_error: 71.4182
# Epoch 87/100
# 181/181 [==============================] - 3s 15ms/step - loss: 9363.9951 - mean_absolute_error: 60.0189 - val_loss: 453140.6875 - val_mean_absolute_error: 75.5144
# Epoch 88/100
# 181/181 [==============================] - 2s 13ms/step - loss: 9467.2881 - mean_absolute_error: 58.0046 - val_loss: 403449.5625 - val_mean_absolute_error: 66.5286
# Epoch 89/100
# 181/181 [==============================] - 3s 15ms/step - loss: 8881.4746 - mean_absolute_error: 55.7754 - val_loss: 414417.9062 - val_mean_absolute_error: 68.5451
# Epoch 90/100
# 181/181 [==============================] - 3s 17ms/step - loss: 7302.9106 - mean_absolute_error: 50.3835 - val_loss: 392977.5312 - val_mean_absolute_error: 68.3460
# Epoch 91/100
# 181/181 [==============================] - 3s 15ms/step - loss: 16391.8652 - mean_absolute_error: 56.7117 - val_loss: 353933.3750 - val_mean_absolute_error: 70.1496
# Epoch 92/100
# 181/181 [==============================] - 5s 27ms/step - loss: 11970.1094 - mean_absolute_error: 53.0459 - val_loss: 373285.7812 - val_mean_absolute_error: 84.3998
# Epoch 93/100
# 181/181 [==============================] - 3s 18ms/step - loss: 10501.0010 - mean_absolute_error: 50.2828 - val_loss: 270525.8125 - val_mean_absolute_error: 59.7449
# Epoch 94/100
# 181/181 [==============================] - 4s 23ms/step - loss: 6688.2588 - mean_absolute_error: 45.8483 - val_loss: 257995.2969 - val_mean_absolute_error: 51.9742
# Epoch 95/100
# 181/181 [==============================] - 3s 15ms/step - loss: 5554.0654 - mean_absolute_error: 41.9243 - val_loss: 218998.7188 - val_mean_absolute_error: 60.0832
# Epoch 96/100
# 181/181 [==============================] - 3s 17ms/step - loss: 5614.7720 - mean_absolute_error: 43.5817 - val_loss: 279732.7188 - val_mean_absolute_error: 53.4563
# Epoch 97/100
# 181/181 [==============================] - 4s 20ms/step - loss: 6265.0469 - mean_absolute_error: 39.6814 - val_loss: 194843.4219 - val_mean_absolute_error: 49.2407
# Epoch 98/100
# 181/181 [==============================] - 4s 20ms/step - loss: 7045.9678 - mean_absolute_error: 40.2377 - val_loss: 249152.9062 - val_mean_absolute_error: 48.0671
# Epoch 99/100
# 181/181 [==============================] - 3s 17ms/step - loss: 9195.9287 - mean_absolute_error: 39.3268 - val_loss: 264222.1562 - val_mean_absolute_error: 77.0929
# Epoch 100/100
# 181/181 [==============================] - 4s 20ms/step - loss: 14453.3438 - mean_absolute_error: 47.3159 - val_loss: 207720.1562 - val_mean_absolute_error: 57.4275
# 78/78 [==============================] - 1s 9ms/step - loss: 207720.1562 - mean_absolute_error: 57.4275
# Mean Squared Error (Neural Network): 207720.15625
# Mean Absolute Error (Neural Network): 57.42751693725586
# 1/1 [==============================] - 1s 826ms/step
# Predicted Rent (Neural Network): 340892.6
