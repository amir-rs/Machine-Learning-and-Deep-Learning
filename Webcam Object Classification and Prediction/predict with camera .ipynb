# %%
import keras
import cv2
import os
from keras.applications.vgg16 import VGG16  # Import VGG16 directly

conv_base = VGG16(weights='imagenet',  # Instantiate VGG16 model
                 include_top=False,
                 input_shape=(224,224,3))

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ...

# %%
base_dir = os.path.expanduser('./name_directory')
os.makedirs(base_dir, exist_ok=True)
base_dir

# %%
import pathlib
pathlib.Path("/tmp/path/to/desired/directory").mkdir(parents=True, exist_ok=True)

# %% [markdown]
# enter the name of the class in the cell below where you want to capture and save a photho using the webcam.
# After taking the desired number of photos for adding a new class, you just need to change the file name 'cls' to the desired name of the new class

# %%
cls = '#' # name your class 
c = 0
path = os.path.join(base_dir, cls)
os.makedirs(path, exist_ok=True)

cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: Unable to open webcam.")
    exit()

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Failed to receive frame from webcam.")
        break

    frame = cv2.resize(frame, (224, 224))
    cv2.imshow('webcam', frame)
    key = cv2.waitKey(1)
    if key == 13:  # Enter key
        break
    elif key == 32:  # Space key
        c += 1
        image_path = os.path.join(path, str(c) + '.png')
        print('Save to:', image_path)
        cv2.imwrite(image_path, frame)

cap.release()
cv2.destroyAllWindows()

# %%
total = 0
for root, dirs , files in os.walk('./hand_dataset'):
    total += len(files)

print('total fill in directory: ', total)
# Out:
# total fill in directory:  355

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16

conv_base = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

datagen = ImageDataGenerator(rescale=1./255)
batch_size = 25

def extract_features(directory, sample_count):
    features = np.zeros(shape=(sample_count, 7, 7, 512))
    labels = np.zeros(shape=(sample_count,))
    generator = datagen.flow_from_directory(
        directory,
        target_size=(224, 224),
        batch_size=batch_size,
        class_mode='categorical')
    i = 0
    for inputs_batch, labels_batch in generator:
        features_batch = conv_base.predict(inputs_batch)
        features[i * batch_size : (i + 1) * batch_size] = features_batch
        labels[i * batch_size : (i + 1) * batch_size] = np.argmax(labels_batch, axis=1)
        i += 1
        if i * batch_size >= sample_count:
            break
    return features, labels, generator.class_indices

train_features, train_labels, dictionary = extract_features(base_dir, total)
# Out:
# Found 355 images belonging to 4 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step

# %%
import numpy as np
train_features = np.reshape(train_features, (-1, 7 * 7 * 512))

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(train_features, train_labels)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
dictionary
# Out:
# {'1': 0, '2': 1, '5': 2, 'Fuck U': 3}

# %%
def get_class_name(label):
    for name, lbl in dictionary.items():
        if lbl == label:
            return name

# %%
get_class_name(0)
# Out:
# '1'

# %%
import cv2
from keras.applications.vgg16 import preprocess_input  # Import preprocess_input from Keras

cap  = cv2.VideoCapture(0)
while True:
    ret , frame = cap.read()
    frame = cv2.resize(frame, (224, 224))
    x = np.expand_dims(frame, axis=0)
    x = preprocess_input(x)
    feature = conv_base.predict(x)
    feature = np.reshape(feature, (-1, 7 * 7 * 512))
    predicted = neigh.predict(feature)
    text = get_class_name(predicted[0])
    cv2.putText(frame, text, (30, 30), cv2.FONT_HERSHEY_SCRIPT_COMPLEX, 1.0, (255, 255, 255), 1)
    cv2.imshow('Webcam', frame)
    if cv2.waitKey(1) == 13:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# ...
